# %%
import pandas as pd

# %%
#Files to load 
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# %%
school_data_df = pd.read_csv(school_data_to_load)
student_data_df = pd.read_csv(student_data_to_load)

# %%
school_data_df
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
# Add each prefix and suffix to remove to a list.
prefixes_suffixes = ["Dr. ", "Mr. ","Ms. ", "Mrs. ", "Miss ", " MD", " DDS", " DVM", " PhD"]

# %%
# Iterate through the words in the "prefixes_suffixes" list and replace them with an empty space, "".
for word in prefixes_suffixes:
    student_data_df["student_name"] = student_data_df["student_name"].str.replace(word,"")

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# 2                 90          60
# ...

# %%
import numpy as np

# %%
# Replace math score with NaN by iterating through columns and values.
for col in ["math_score", "reading_score"]:
    student_data_df.loc[(student_data_df["grade"] == "9th")
                            & (student_data_df["school_name"] == "Thomas High School"), col] = np.nan

# %%
student_data_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0               66.0        79.0
# 1               94.0        61.0
# 2               90.0        60.0
# ...

# %%
# Combine the data into a single dataset.
school_data_new_df = pd.merge(student_data_df, school_data_df, on=["school_name", "school_name"])
school_data_new_df.head()
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 0           0     Paul Bradley      M   9th  Huang High School           66.0
# 1           1     Victor Smith      M  12th  Huang High School           94.0
# 2           2  Kevin Rodriguez      M  12th  Huang High School           90.0
# 3           3    Richard Scott      M  12th  Huang High School           67.0
# 4           4       Bonnie Ray      F   9th  Huang High School           97.0
#
#    math_score  School ID      type  size   budget
# 0        79.0          0  District  2917  1910635
# 1        61.0          0  District  2917  1910635
# 2        60.0          0  District  2917  1910635
# 3        58.0          0  District  2917  1910635
# 4        84.0          0  District  2917  1910635

# %%
school_data_new_df
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0               66.0        79.0          0  District  2917  1910635
# ...

# %%
# Calculate the total budget.
total_budget_new = school_data_new_df["budget"].sum()
total_budget_new
# Out:
# 82932329558

# %%
# Calculate the total budget.
total_budget_new = school_data_df["budget"].sum()
total_budget_new
# Out:
# 24649428

# %%
# Calculate the average reading score.
average_reading_score_new = school_data_new_df["reading_score"].mean()
average_reading_score_new
# Out:
# 81.85579580976001

# %%
# Calculate the average math score.
average_math_score_new = school_data_new_df["math_score"].mean()
average_math_score_new
# Out:
# 78.93053295099331

# %%
passing_math_new = school_data_new_df["math_score"] >= 70
passing_reading_new = school_data_new_df["reading_score"] >= 70

# %%
passing_math_new
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4         True
#          ...
# 39165     True
# 39166     True
# 39167    False
# 39168     True
# 39169     True
# Name: math_score, Length: 39170, dtype: bool

# %%
passing_reading_new
# Out:
# 0        False
# 1         True
# 2         True
# 3        False
# 4         True
#          ...
# 39165     True
# 39166     True
# 39167    False
# 39168     True
# 39169     True
# Name: reading_score, Length: 39170, dtype: bool

# %%
# Get all the students who are passing math in a new DataFrame.
passing_math_new = school_data_new_df[school_data_new_df["math_score"] >= 70]
passing_math_new.head()
# Out:
#    Student ID   student_name gender grade        school_name  reading_score  \
# 0           0   Paul Bradley      M   9th  Huang High School           66.0
# 4           4     Bonnie Ray      F   9th  Huang High School           97.0
# 5           5  Bryan Miranda      M   9th  Huang High School           94.0
# 6           6  Sheena Carter      F  11th  Huang High School           82.0
# 8           8   Michael Roth      M  10th  Huang High School           95.0
#
#    math_score  School ID      type  size   budget
# 0        79.0          0  District  2917  1910635
# 4        84.0          0  District  2917  1910635
# 5        94.0          0  District  2917  1910635
# 6        80.0          0  District  2917  1910635
# 8        87.0          0  District  2917  1910635

# %%
# Get all the students that are passing reading in a new DataFrame.
passing_reading_new = school_data_new_df[school_data_new_df["reading_score"] >= 70]

# %%
passing_reading_new.head()
# Out:
#    Student ID     student_name gender grade        school_name  reading_score  \
# 1           1     Victor Smith      M  12th  Huang High School           94.0
# 2           2  Kevin Rodriguez      M  12th  Huang High School           90.0
# 4           4       Bonnie Ray      F   9th  Huang High School           97.0
# 5           5    Bryan Miranda      M   9th  Huang High School           94.0
# 6           6    Sheena Carter      F  11th  Huang High School           82.0
#
#    math_score  School ID      type  size   budget
# 1        61.0          0  District  2917  1910635
# 2        60.0          0  District  2917  1910635
# 4        84.0          0  District  2917  1910635
# 5        94.0          0  District  2917  1910635
# 6        80.0          0  District  2917  1910635

# %%
# Calculate the number of students passing math.
passing_math_count_new = passing_math_new["student_name"].count()

# Calculate the number of students passing reading.
passing_reading_count_new = passing_reading_new["student_name"].count()

# %%
passing_math_count_new
# Out:
# 28939

# %%
passing_reading_count_new
# Out:
# 33158

# %%
student_count_new = school_data_new_df["Student ID"].count()
student_count_new
# Out:
# 39170

# %%
# Calculate the percent that passed math.
passing_math_percentage_new = passing_math_count_new / float(student_count_new) * 100

# Calculate the percent that passed reading.
passing_reading_percentage_new = passing_reading_count_new/ float(student_count_new) * 100

# %%
passing_math_percentage_new
# Out:
# 73.88052080673985

# %%
passing_reading_percentage_new
# Out:
# 84.65151901965791

# %%
# Calculate the students who passed both math and reading.
passing_math_reading_new = school_data_new_df[(school_data_new_df["math_score"] >= 70) & (school_data_new_df["reading_score"] >= 70)]

passing_math_reading_new.head()
# Out:
#    Student ID    student_name gender grade        school_name  reading_score  \
# 4           4      Bonnie Ray      F   9th  Huang High School           97.0
# 5           5   Bryan Miranda      M   9th  Huang High School           94.0
# 6           6   Sheena Carter      F  11th  Huang High School           82.0
# 8           8    Michael Roth      M  10th  Huang High School           95.0
# 9           9  Matthew Greene      M  10th  Huang High School           96.0
#
#    math_score  School ID      type  size   budget
# 4        84.0          0  District  2917  1910635
# 5        94.0          0  District  2917  1910635
# 6        80.0          0  District  2917  1910635
# 8        87.0          0  District  2917  1910635
# 9        84.0          0  District  2917  1910635

# %%
# Calculate the number of students who passed both math and reading.
overall_passing_math_reading_count_new = passing_math_reading_new["student_name"].count()
overall_passing_math_reading_count_new
# Out:
# 25105

# %%
# Calculate the overall passing percentage.
overall_passing_percentage_new = overall_passing_math_reading_count_new / student_count_new * 100
overall_passing_percentage_new
# Out:
# 64.09241766658157

# %%
# Calculate the total number of schools.
school_count_new = school_data_df["school_name"].count()
school_count_new
# Out:
# 15

# %%
# Calculate the total number of schools
school_count_2_new = school_data_df["school_name"].unique()
school_count_2_new
# Out:
# array(['Huang High School', 'Figueroa High School', 'Shelton High School',
#        'Hernandez High School', 'Griffin High School',
#        'Wilson High School', 'Cabrera High School', 'Bailey High School',
#        'Holden High School', 'Pena High School', 'Wright High School',
#        'Rodriguez High School', 'Johnson High School', 'Ford High School',
#        'Thomas High School'], dtype=object)

# %%
# Adding a list of values with keys to create a new DataFrame.
district_summary_new_df = pd.DataFrame(
          [{"Total Schools": school_count_new,
          "Total Students": student_count_new,
          "Total Budget": total_budget_new,
          "Average Math Score": average_math_score_new,
          "Average Reading Score": average_reading_score_new,
          "% Passing Math": passing_math_percentage_new,
         "% Passing Reading": passing_reading_percentage_new,
        "% Overall Passing": overall_passing_percentage_new}])
district_summary_new_df
# Out:
#    Total Schools  Total Students  Total Budget  Average Math Score  \
# 0             15           39170      24649428           78.930533
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0              81.855796       73.880521          84.651519          64.092418

# %%
# Define a function that calculates the percentage of students that passed both # math and reading and prints the passing percentage to the output when the
# function is called.
def passing_math_percent_new(pass_math_count_new, student_count_new):
    return pass_math_count_new / float(student_count_new) * 100

# %%
passing_math_count_new = 28939
total_student_count_new = 39170

# %%
# Call the function.
passing_math_percent_new(passing_math_count_new, total_student_count_new)
# Out:
# 73.88052080673985

# %%
# Format the "Total Students" to have the comma for a thousands separator.
district_summary_new_df["Total Students"] = district_summary_new_df["Total Students"].map("{:,}".format)

district_summary_new_df["Total Students"]
# Out:
# 0    39,170
# Name: Total Students, dtype: object

# %%
# Format "Total Budget" to have the comma for a thousands separator, a decimal separator, and a "$".

district_summary_new_df["Total Budget"] = district_summary_new_df["Total Budget"].map("${:,.2f}".format)

district_summary_new_df["Total Budget"]
# Out:
# 0    $24,649,428.00
# Name: Total Budget, dtype: object

# %%
# Format the columns.
district_summary_new_df["Average Math Score"] = district_summary_new_df["Average Math Score"].map("{:.1f}".format)

district_summary_new_df["Average Reading Score"] = district_summary_new_df["Average Reading Score"].map("{:.1f}".format)

district_summary_new_df["% Passing Math"] = district_summary_new_df["% Passing Math"].map("{:.0f}".format)

district_summary_new_df["% Passing Reading"] = district_summary_new_df["% Passing Reading"].map("{:.0f}".format)

district_summary_new_df["% Overall Passing"] = district_summary_new_df["% Overall Passing"].map("{:.0f}".format)

# %%
district_summary_new_df
# Out:
#    Total Schools Total Students    Total Budget Average Math Score  \
# 0             15         39,170  $24,649,428.00               78.9
#
#   Average Reading Score % Passing Math % Passing Reading % Overall Passing
# 0                  81.9             74                85                64

# %%
# Determine the school type.
per_school_types_new = school_data_df.set_index(["school_name"])["type"]
per_school_types_new
# Out:
# school_name
# Huang High School        District
# Figueroa High School     District
# Shelton High School       Charter
# Hernandez High School    District
# Griffin High School       Charter
# Wilson High School        Charter
# Cabrera High School       Charter
# Bailey High School       District
# Holden High School        Charter
# Pena High School          Charter
# Wright High School        Charter
# Rodriguez High School    District
# Johnson High School      District
# Ford High School         District
# Thomas High School        Charter
# Name: type, dtype: object

# %%
# Add the per_school_types into a DataFrame for testing.
df = pd.DataFrame(per_school_types_new)
df
# Out:
#                            type
# school_name
# Huang High School      District
# Figueroa High School   District
# Shelton High School     Charter
# Hernandez High School  District
# Griffin High School     Charter
# Wilson High School      Charter
# Cabrera High School     Charter
# Bailey High School     District
# Holden High School      Charter
# Pena High School        Charter
# Wright High School      Charter
# Rodriguez High School  District
# Johnson High School    District
# Ford High School       District
# Thomas High School      Charter

# %%
# Calculate the total student count.
per_school_counts_new = school_data_df["size"]
per_school_counts_new
# Out:
# 0     2917
# 1     2949
# 2     1761
# 3     4635
# 4     1468
# 5     2283
# 6     1858
# 7     4976
# 8      427
# 9      962
# 10    1800
# 11    3999
# 12    4761
# 13    2739
# 14    1635
# Name: size, dtype: int64

# %%
# Calculate the total student count.
per_school_counts_new = school_data_df.set_index(["school_name"])["size"]
per_school_counts_new
# Out:
# school_name
# Huang High School        2917
# Figueroa High School     2949
# Shelton High School      1761
# Hernandez High School    4635
# Griffin High School      1468
# Wilson High School       2283
# Cabrera High School      1858
# Bailey High School       4976
# Holden High School        427
# Pena High School          962
# Wright High School       1800
# Rodriguez High School    3999
# Johnson High School      4761
# Ford High School         2739
# Thomas High School       1635
# Name: size, dtype: int64

# %%
# Calculate the total student count.
per_school_counts_new = school_data_new_df["school_name"].value_counts()
per_school_counts_new
# Out:
# Bailey High School       4976
# Johnson High School      4761
# Hernandez High School    4635
# Rodriguez High School    3999
# Figueroa High School     2949
# Huang High School        2917
# Ford High School         2739
# Wilson High School       2283
# Cabrera High School      1858
# Wright High School       1800
# Shelton High School      1761
# Thomas High School       1635
# Griffin High School      1468
# Pena High School          962
# Holden High School        427
# Name: school_name, dtype: int64

# %%
# Calculate the total school budget.
per_school_budget_new = school_data_df.set_index(["school_name"])["budget"]
per_school_budget_new
# Out:
# school_name
# Huang High School        1910635
# Figueroa High School     1884411
# Shelton High School      1056600
# Hernandez High School    3022020
# Griffin High School       917500
# Wilson High School       1319574
# Cabrera High School      1081356
# Bailey High School       3124928
# Holden High School        248087
# Pena High School          585858
# Wright High School       1049400
# Rodriguez High School    2547363
# Johnson High School      3094650
# Ford High School         1763916
# Thomas High School       1043130
# Name: budget, dtype: int64

# %%
# Calculate the per capita spending.
per_school_capita_new = per_school_budget_new / per_school_counts_new
per_school_capita_new
# Out:
# Bailey High School       628.0
# Cabrera High School      582.0
# Figueroa High School     639.0
# Ford High School         644.0
# Griffin High School      625.0
# Hernandez High School    652.0
# Holden High School       581.0
# Huang High School        655.0
# Johnson High School      650.0
# Pena High School         609.0
# Rodriguez High School    637.0
# Shelton High School      600.0
# Thomas High School       638.0
# Wilson High School       578.0
# Wright High School       583.0
# dtype: float64

# %%
# Calculate the math scores.
student_school_name_new = student_data_df.set_index(["school_name"])["math_score"]

# %%
student_school_name_new
# Out:
# school_name
# Huang High School     79.0
# Huang High School     61.0
# Huang High School     60.0
# Huang High School     58.0
# Huang High School     84.0
#                       ...
# Thomas High School    90.0
# Thomas High School    70.0
# Thomas High School     NaN
# Thomas High School    90.0
# Thomas High School    75.0
# Name: math_score, Length: 39170, dtype: float64

# %%
# Calculate the average math scores.
per_school_averages_new = school_data_new_df.groupby(["school_name"]).mean()
per_school_averages_new
# Out:
#                        Student ID  reading_score  math_score  School ID  \
# school_name
# Bailey High School        20358.5      81.033963   77.048432        7.0
# Cabrera High School       16941.5      83.975780   83.061895        6.0
# Figueroa High School       4391.0      81.158020   76.711767        1.0
# Ford High School          36165.0      80.746258   77.102592       13.0
# Griffin High School       12995.5      83.816757   83.351499        4.0
# Hernandez High School      9944.0      80.934412   77.289752        3.0
# Holden High School        23060.0      83.814988   83.803279        8.0
# Huang High School          1458.0      81.182722   76.629414        0.0
# Johnson High School       32415.0      80.966394   77.072464       12.0
# Pena High School          23754.5      84.044699   83.839917        9.0
# Rodriguez High School     28035.0      80.744686   76.842711       11.0
# Shelton High School        6746.0      83.725724   83.359455        2.0
# ...

# %%
# Calculate the average test scores.
per_school_math_new = school_data_new_df.groupby(["school_name"]).mean()["math_score"]

per_school_reading_new = school_data_new_df.groupby(["school_name"]).mean()["reading_score"]

# %%
per_school_math_new
# Out:
# school_name
# Bailey High School       77.048432
# Cabrera High School      83.061895
# Figueroa High School     76.711767
# Ford High School         77.102592
# Griffin High School      83.351499
# Hernandez High School    77.289752
# Holden High School       83.803279
# Huang High School        76.629414
# Johnson High School      77.072464
# Pena High School         83.839917
# Rodriguez High School    76.842711
# Shelton High School      83.359455
# Thomas High School       83.350937
# Wilson High School       83.274201
# Wright High School       83.682222
# Name: math_score, dtype: float64

# %%
per_school_reading_new
# Out:
# school_name
# Bailey High School       81.033963
# Cabrera High School      83.975780
# Figueroa High School     81.158020
# Ford High School         80.746258
# Griffin High School      83.816757
# Hernandez High School    80.934412
# Holden High School       83.814988
# Huang High School        81.182722
# Johnson High School      80.966394
# Pena High School         84.044699
# Rodriguez High School    80.744686
# Shelton High School      83.725724
# Thomas High School       83.896082
# Wilson High School       83.989488
# Wright High School       83.955000
# Name: reading_score, dtype: float64

# %%
# Calculate the passing scores by creating a filtered DataFrame.
per_school_passing_math_new = school_data_new_df[(school_data_new_df["math_score"] >= 70)]

per_school_passing_reading_new = school_data_new_df[(school_data_new_df["reading_score"] >= 70)]

# %%
per_school_passing_math_new
# Out:
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# 8               8     Michael Roth      M  10th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39163       39163       John Reese      M  11th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0               66.0        79.0          0  District  2917  1910635
# ...

# %%
per_school_passing_reading_new
# Out:
#        Student ID     student_name gender grade         school_name  \
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# 5               5    Bryan Miranda      M   9th   Huang High School
# 6               6    Sheena Carter      F  11th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39163       39163       John Reese      M  11th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1               94.0        61.0          0  District  2917  1910635
# ...

# %%
# Calculate the number of students passing math and passing reading by school.
per_school_passing_math_new = per_school_passing_math_new.groupby(["school_name"]).count()["student_name"]

per_school_passing_reading_new = per_school_passing_reading_new.groupby(["school_name"]).count()["student_name"]

# %%
per_school_passing_math_new
# Out:
# school_name
# Bailey High School       3318
# Cabrera High School      1749
# Figueroa High School     1946
# Ford High School         1871
# Griffin High School      1371
# Hernandez High School    3094
# Holden High School        395
# Huang High School        1916
# Johnson High School      3145
# Pena High School          910
# Rodriguez High School    2654
# Shelton High School      1653
# Thomas High School       1094
# Wilson High School       2143
# Wright High School       1680
# Name: student_name, dtype: int64

# %%
per_school_passing_reading_new
# Out:
# school_name
# Bailey High School       4077
# Cabrera High School      1803
# Figueroa High School     2381
# Ford High School         2172
# Griffin High School      1426
# Hernandez High School    3748
# Holden High School        411
# Huang High School        2372
# Johnson High School      3867
# Pena High School          923
# Rodriguez High School    3208
# Shelton High School      1688
# Thomas High School       1139
# Wilson High School       2204
# Wright High School       1739
# Name: student_name, dtype: int64

# %%
# Calculate the percentage of passing math and reading scores per school.
per_school_passing_math_new = per_school_passing_math_new/ per_school_counts_new * 100

per_school_passing_reading_new = per_school_passing_reading_new / per_school_counts_new * 100

# %%
per_school_passing_math_new
# Out:
# Bailey High School       66.680064
# Cabrera High School      94.133477
# Figueroa High School     65.988471
# Ford High School         68.309602
# Griffin High School      93.392371
# Hernandez High School    66.752967
# Holden High School       92.505855
# Huang High School        65.683922
# Johnson High School      66.057551
# Pena High School         94.594595
# Rodriguez High School    66.366592
# Shelton High School      93.867121
# Thomas High School       66.911315
# Wilson High School       93.867718
# Wright High School       93.333333
# dtype: float64

# %%
per_school_passing_reading_new
# Out:
# Bailey High School       81.933280
# Cabrera High School      97.039828
# Figueroa High School     80.739234
# Ford High School         79.299014
# Griffin High School      97.138965
# Hernandez High School    80.862999
# Holden High School       96.252927
# Huang High School        81.316421
# Johnson High School      81.222432
# Pena High School         95.945946
# Rodriguez High School    80.220055
# Shelton High School      95.854628
# Thomas High School       69.663609
# Wilson High School       96.539641
# Wright High School       96.611111
# dtype: float64

# %%
# Calculate the students who passed both math and reading.
per_passing_math_reading_new = school_data_new_df[(school_data_new_df["math_score"] >= 70) & (school_data_new_df["reading_score"] >= 70)]

per_passing_math_reading_new.head()
# Out:
#    Student ID    student_name gender grade        school_name  reading_score  \
# 4           4      Bonnie Ray      F   9th  Huang High School           97.0
# 5           5   Bryan Miranda      M   9th  Huang High School           94.0
# 6           6   Sheena Carter      F  11th  Huang High School           82.0
# 8           8    Michael Roth      M  10th  Huang High School           95.0
# 9           9  Matthew Greene      M  10th  Huang High School           96.0
#
#    math_score  School ID      type  size   budget
# 4        84.0          0  District  2917  1910635
# 5        94.0          0  District  2917  1910635
# 6        80.0          0  District  2917  1910635
# 8        87.0          0  District  2917  1910635
# 9        84.0          0  District  2917  1910635

# %%
per_passing_math_reading_new.tail()
# Out:
#        Student ID     student_name gender grade         school_name  \
# 39163       39163       John Reese      M  11th  Thomas High School
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# 39169       39169  Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID     type  size   budget
# 39163           90.0        75.0         14  Charter  1635  1043130
# 39165           99.0        90.0         14  Charter  1635  1043130
# 39166           95.0        70.0         14  Charter  1635  1043130
# 39168           99.0        90.0         14  Charter  1635  1043130
# 39169           95.0        75.0         14  Charter  1635  1043130

# %%
# Calculate the number of students who passed both math and reading.
per_passing_math_reading_new = per_passing_math_reading_new.groupby(["school_name"]).count()["student_name"]

# %%
per_passing_math_reading_new
# Out:
# school_name
# Bailey High School       2719
# Cabrera High School      1697
# Figueroa High School     1569
# Ford High School         1487
# Griffin High School      1330
# Hernandez High School    2481
# Holden High School        381
# Huang High School        1561
# Johnson High School      2549
# Pena High School          871
# Rodriguez High School    2119
# Shelton High School      1583
# Thomas High School       1064
# Wilson High School       2068
# Wright High School       1626
# Name: student_name, dtype: int64

# %%
# Calculate the overall passing percentage.
per_overall_passing_percentage_new = per_passing_math_reading_new / per_school_counts_new * 100

# %%
per_overall_passing_percentage_new
# Out:
# Bailey High School       54.642283
# Cabrera High School      91.334769
# Figueroa High School     53.204476
# Ford High School         54.289887
# Griffin High School      90.599455
# Hernandez High School    53.527508
# Holden High School       89.227166
# Huang High School        53.513884
# Johnson High School      53.539172
# Pena High School         90.540541
# Rodriguez High School    52.988247
# Shelton High School      89.892107
# Thomas High School       65.076453
# Wilson High School       90.582567
# Wright High School       90.333333
# dtype: float64

# %%
# Adding a list of values with keys to create a new DataFrame.

per_school_summary_new_df = pd.DataFrame({
             "School Type": per_school_types_new,
             "Total Students": per_school_counts_new,
             "Total School Budget": per_school_budget_new,
             "Per Student Budget": per_school_capita_new,
             "Average Math Score": per_school_math_new,
           "Average Reading Score": per_school_reading_new,
           "% Passing Math": per_school_passing_math_new,
           "% Passing Reading": per_school_passing_reading_new,
           "% Overall Passing": per_overall_passing_percentage_new})
per_school_summary_new_df.head()
# Out:
#                      School Type  Total Students  Total School Budget  \
# Bailey High School      District            4976              3124928
# Cabrera High School      Charter            1858              1081356
# Figueroa High School    District            2949              1884411
# Ford High School        District            2739              1763916
# Griffin High School      Charter            1468               917500
#
#                       Per Student Budget  Average Math Score  \
# Bailey High School                 628.0           77.048432
# Cabrera High School                582.0           83.061895
# Figueroa High School               639.0           76.711767
# Ford High School                   644.0           77.102592
# Griffin High School                625.0           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# ...

# %%
per_school_summary_new_df
# Out:
#                       School Type  Total Students  Total School Budget  \
# Bailey High School       District            4976              3124928
# Cabrera High School       Charter            1858              1081356
# Figueroa High School     District            2949              1884411
# Ford High School         District            2739              1763916
# Griffin High School       Charter            1468               917500
# Hernandez High School    District            4635              3022020
# Holden High School        Charter             427               248087
# Huang High School        District            2917              1910635
# Johnson High School      District            4761              3094650
# Pena High School          Charter             962               585858
# Rodriguez High School    District            3999              2547363
# Shelton High School       Charter            1761              1056600
# ...

# %%
# Format the Total School Budget and the Per Student Budget columns.
per_school_summary_new_df["Total School Budget"] = per_school_summary_new_df["Total School Budget"].map("${:,.2f}".format)

per_school_summary_new_df["Per Student Budget"] = per_school_summary_new_df["Per Student Budget"].map("${:,.2f}".format)


# Display the data frame
per_school_summary_new_df.head()
# Out:
#                      School Type  Total Students Total School Budget  \
# Bailey High School      District            4976       $3,124,928.00
# Cabrera High School      Charter            1858       $1,081,356.00
# Figueroa High School    District            2949       $1,884,411.00
# Ford High School        District            2739       $1,763,916.00
# Griffin High School      Charter            1468         $917,500.00
#
#                      Per Student Budget  Average Math Score  \
# Bailey High School              $628.00           77.048432
# Cabrera High School             $582.00           83.061895
# Figueroa High School            $639.00           76.711767
# Ford High School                $644.00           77.102592
# Griffin High School             $625.00           83.351499
#
#                       Average Reading Score  % Passing Math  \
# Bailey High School                81.033963       66.680064
# Cabrera High School               83.975780       94.133477
# ...

# %%
# Sort and show top five schools.
top_schools_new = per_school_summary_new_df.sort_values(["% Overall Passing"], ascending=False)

top_schools_new.head()
# Out:
#                     School Type  Total Students Total School Budget  \
# Cabrera High School     Charter            1858       $1,081,356.00
# Griffin High School     Charter            1468         $917,500.00
# Wilson High School      Charter            2283       $1,319,574.00
# Pena High School        Charter             962         $585,858.00
# Wright High School      Charter            1800       $1,049,400.00
#
#                     Per Student Budget  Average Math Score  \
# Cabrera High School            $582.00           83.061895
# Griffin High School            $625.00           83.351499
# Wilson High School             $578.00           83.274201
# Pena High School               $609.00           83.839917
# Wright High School             $583.00           83.682222
#
#                      Average Reading Score  % Passing Math  % Passing Reading  \
# Cabrera High School              83.975780       94.133477          97.039828
# ...

# %%
top_schools_new.tail()
# Out:
#                       School Type  Total Students Total School Budget  \
# Johnson High School      District            4761       $3,094,650.00
# Hernandez High School    District            4635       $3,022,020.00
# Huang High School        District            2917       $1,910,635.00
# Figueroa High School     District            2949       $1,884,411.00
# Rodriguez High School    District            3999       $2,547,363.00
#
#                       Per Student Budget  Average Math Score  \
# Johnson High School              $650.00           77.072464
# Hernandez High School            $652.00           77.289752
# Huang High School                $655.00           76.629414
# Figueroa High School             $639.00           76.711767
# Rodriguez High School            $637.00           76.842711
#
#                        Average Reading Score  % Passing Math  \
# Johnson High School                80.966394       66.057551
# ...

# %%
top_schools_new
# Out:
#                       School Type  Total Students Total School Budget  \
# Cabrera High School       Charter            1858       $1,081,356.00
# Griffin High School       Charter            1468         $917,500.00
# Wilson High School        Charter            2283       $1,319,574.00
# Pena High School          Charter             962         $585,858.00
# Wright High School        Charter            1800       $1,049,400.00
# Shelton High School       Charter            1761       $1,056,600.00
# Holden High School        Charter             427         $248,087.00
# Thomas High School        Charter            1635       $1,043,130.00
# Bailey High School       District            4976       $3,124,928.00
# Ford High School         District            2739       $1,763,916.00
# Johnson High School      District            4761       $3,094,650.00
# Hernandez High School    District            4635       $3,022,020.00
# ...

# %%
# Sort and show top five schools.
bottom_schools_new = per_school_summary_new_df.sort_values(["% Overall Passing"], ascending=True)

bottom_schools_new.head()
# Out:
#                       School Type  Total Students Total School Budget  \
# Rodriguez High School    District            3999       $2,547,363.00
# Figueroa High School     District            2949       $1,884,411.00
# Huang High School        District            2917       $1,910,635.00
# Hernandez High School    District            4635       $3,022,020.00
# Johnson High School      District            4761       $3,094,650.00
#
#                       Per Student Budget  Average Math Score  \
# Rodriguez High School            $637.00           76.842711
# Figueroa High School             $639.00           76.711767
# Huang High School                $655.00           76.629414
# Hernandez High School            $652.00           77.289752
# Johnson High School              $650.00           77.072464
#
#                        Average Reading Score  % Passing Math  \
# Rodriguez High School              80.744686       66.366592
# ...

# %%
# Create a grade level DataFrames.
ninth_graders_new = school_data_new_df[(school_data_new_df["grade"] == "9th")]

tenth_graders_new = school_data_new_df[(school_data_new_df["grade"] == "10th")]

eleventh_graders_new = school_data_new_df[(school_data_new_df["grade"] == "11th")]

twelfth_graders_new = school_data_new_df[(school_data_new_df["grade"] == "12th")]

# %%
ninth_graders_new
# Out:
#        Student ID      student_name gender grade         school_name  \
# 0               0      Paul Bradley      M   9th   Huang High School
# 4               4        Bonnie Ray      F   9th   Huang High School
# 5               5     Bryan Miranda      M   9th   Huang High School
# 12             12   Brittney Walker      F   9th   Huang High School
# 13             13      William Long      M   9th   Huang High School
# ...           ...               ...    ...   ...                 ...
# 39152       39152        Lori Moore      F   9th  Thomas High School
# 39153       39153   William Hubbard      M   9th  Thomas High School
# 39157       39157  Kristen Gonzalez      F   9th  Thomas High School
# 39164       39164    Joseph Anthony      M   9th  Thomas High School
# 39167       39167    Rebecca Tanner      F   9th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 0               66.0        79.0          0  District  2917  1910635
# ...

# %%
tenth_graders_new
# Out:
#        Student ID      student_name gender grade         school_name  \
# 8               8      Michael Roth      M  10th   Huang High School
# 9               9    Matthew Greene      M  10th   Huang High School
# 10             10  Andrew Alexander      M  10th   Huang High School
# 11             11     Daniel Cooper      M  10th   Huang High School
# 14             14      Tammy Hebert      F  10th   Huang High School
# ...           ...               ...    ...   ...                 ...
# 39155       39155       John Brooks      M  10th  Thomas High School
# 39158       39158     Kari Holloway      F  10th  Thomas High School
# 39161       39161       April Reyes      F  10th  Thomas High School
# 39166       39166         Dawn Bell      F  10th  Thomas High School
# 39168       39168      Desiree Kidd      F  10th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 8               95.0        87.0          0  District  2917  1910635
# ...

# %%
eleventh_graders_new
# Out:
#        Student ID         student_name gender grade         school_name  \
# 6               6        Sheena Carter      F  11th   Huang High School
# 15             15        Jordan Carson      M  11th   Huang High School
# 22             22     Kimberly Stewart      F  11th   Huang High School
# 24             24     Chelsea Griffith      F  11th   Huang High School
# 28             28          Kelly James      F  11th   Huang High School
# ...           ...                  ...    ...   ...                 ...
# 39156       39156  Stephanie Contreras      F  11th  Thomas High School
# 39159       39159     Kimberly Cabrera      F  11th  Thomas High School
# 39160       39160         Katie Weaver      F  11th  Thomas High School
# 39163       39163           John Reese      M  11th  Thomas High School
# 39169       39169      Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %%
twelfth_graders_new
# Out:
#        Student ID      student_name gender grade         school_name  \
# 1               1      Victor Smith      M  12th   Huang High School
# 2               2   Kevin Rodriguez      M  12th   Huang High School
# 3               3     Richard Scott      M  12th   Huang High School
# 7               7      Nicole Baker      F  12th   Huang High School
# 29             29      Nicole Brown      F  12th   Huang High School
# ...           ...               ...    ...   ...                 ...
# 39137       39137   Victoria Bailey      F  12th  Thomas High School
# 39144       39144  Cristian Webster      M  12th  Thomas High School
# 39154       39154   Bradley Johnson      M  12th  Thomas High School
# 39162       39162       Derek Weeks      M  12th  Thomas High School
# 39165       39165      Donna Howard      F  12th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# 1               94.0        61.0          0  District  2917  1910635
# ...

# %%
# Group each school Series by the school name for the average math score.
ninth_grade_math_scores_new = ninth_graders_new.groupby(["school_name"]).mean()["math_score"]

tenth_grade_math_scores_new = tenth_graders_new.groupby(["school_name"]).mean()["math_score"]

eleventh_grade_math_scores_new = eleventh_graders_new.groupby(["school_name"]).mean()["math_score"]

twelfth_grade_math_scores_new = twelfth_graders_new.groupby(["school_name"]).mean()["math_score"]

# %%
ninth_grade_math_scores_new
# Out:
# school_name
# Bailey High School       77.083676
# Cabrera High School      83.094697
# Figueroa High School     76.403037
# Ford High School         77.361345
# Griffin High School      82.044010
# Hernandez High School    77.438495
# Holden High School       83.787402
# Huang High School        77.027251
# Johnson High School      77.187857
# Pena High School         83.625455
# Rodriguez High School    76.859966
# Shelton High School      83.420755
# Thomas High School             NaN
# Wilson High School       83.085578
# Wright High School       83.264706
# Name: math_score, dtype: float64

# %%
tenth_grade_math_scores_new
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
tenth_grade_math_scores_new
# Out:
# school_name
# Bailey High School       76.996772
# Cabrera High School      83.154506
# Figueroa High School     76.539974
# Ford High School         77.672316
# Griffin High School      84.229064
# Hernandez High School    77.337408
# Holden High School       83.429825
# Huang High School        75.908735
# Johnson High School      76.691117
# Pena High School         83.372000
# Rodriguez High School    76.612500
# Shelton High School      82.917411
# Thomas High School       83.087886
# Wilson High School       83.724422
# Wright High School       84.010288
# Name: math_score, dtype: float64

# %%
eleventh_grade_math_scores_new
# Out:
# school_name
# Bailey High School       77.515588
# Cabrera High School      82.765560
# Figueroa High School     76.884344
# Ford High School         76.918058
# Griffin High School      83.842105
# Hernandez High School    77.136029
# Holden High School       85.000000
# Huang High School        76.446602
# Johnson High School      77.491653
# Pena High School         84.328125
# Rodriguez High School    76.395626
# Shelton High School      83.383495
# Thomas High School       83.498795
# Wilson High School       83.195326
# Wright High School       83.836782
# Name: math_score, dtype: float64

# %%
twelfth_grade_math_scores_new
# Out:
# school_name
# Bailey High School       76.492218
# Cabrera High School      83.277487
# Figueroa High School     77.151369
# Ford High School         76.179963
# Griffin High School      83.356164
# Hernandez High School    77.186567
# Holden High School       82.855422
# Huang High School        77.225641
# Johnson High School      76.863248
# Pena High School         84.121547
# Rodriguez High School    77.690748
# Shelton High School      83.778976
# Thomas High School       83.497041
# Wilson High School       83.035794
# Wright High School       83.644986
# Name: math_score, dtype: float64

# %%
# Group each school Series by the school name for the average reading score.
ninth_grade_reading_scores_new = ninth_graders_new.groupby(["school_name"]).mean()["reading_score"]

tenth_grade_reading_scores_new = tenth_graders_new.groupby(["school_name"]).mean()["reading_score"]

eleventh_grade_reading_scores_new = eleventh_graders_new.groupby(["school_name"]).mean()["reading_score"]

twelfth_grade_reading_scores_new = twelfth_graders_new.groupby(["school_name"]).mean()["reading_score"]

# %%
ninth_grade_reading_scores_new
# Out:
# school_name
# Bailey High School       81.303155
# Cabrera High School      83.676136
# Figueroa High School     81.198598
# Ford High School         80.632653
# Griffin High School      83.369193
# Hernandez High School    80.866860
# Holden High School       83.677165
# Huang High School        81.290284
# Johnson High School      81.260714
# Pena High School         83.807273
# Rodriguez High School    80.993127
# Shelton High School      84.122642
# Thomas High School             NaN
# Wilson High School       83.939778
# Wright High School       83.833333
# Name: reading_score, dtype: float64

# %%
tenth_grade_reading_scores_new
# Out:
# school_name
# Bailey High School       80.907183
# Cabrera High School      84.253219
# Figueroa High School     81.408912
# Ford High School         81.262712
# Griffin High School      83.706897
# Hernandez High School    80.660147
# Holden High School       83.324561
# Huang High School        81.512386
# Johnson High School      80.773431
# Pena High School         83.612000
# Rodriguez High School    80.629808
# Shelton High School      83.441964
# Thomas High School       84.254157
# Wilson High School       84.021452
# Wright High School       83.812757
# Name: reading_score, dtype: float64

# %%
eleventh_grade_reading_scores_new
# Out:
# school_name
# Bailey High School       80.945643
# Cabrera High School      83.788382
# Figueroa High School     80.640339
# Ford High School         80.403642
# Griffin High School      84.288089
# Hernandez High School    81.396140
# Holden High School       83.815534
# Huang High School        81.417476
# Johnson High School      80.616027
# Pena High School         84.335938
# Rodriguez High School    80.864811
# Shelton High School      84.373786
# Thomas High School       83.585542
# Wilson High School       83.764608
# Wright High School       84.156322
# Name: reading_score, dtype: float64

# %%
twelfth_grade_reading_scores_new
# Out:
# school_name
# Bailey High School       80.912451
# Cabrera High School      84.287958
# Figueroa High School     81.384863
# Ford High School         80.662338
# Griffin High School      84.013699
# Hernandez High School    80.857143
# Holden High School       84.698795
# Huang High School        80.305983
# Johnson High School      81.227564
# Pena High School         84.591160
# Rodriguez High School    80.376426
# Shelton High School      82.781671
# Thomas High School       83.831361
# Wilson High School       84.317673
# Wright High School       84.073171
# Name: reading_score, dtype: float64

# %%
# Combine each Series for average math scores by school into single DataFrame.
math_scores_by_grade_new = pd.DataFrame({
               "9th": ninth_grade_math_scores_new,
               "10th": tenth_grade_math_scores_new,
               "11th": eleventh_grade_math_scores_new,
               "12th": twelfth_grade_math_scores_new})

math_scores_by_grade_new
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     77.083676  76.996772  77.515588  76.492218
# Cabrera High School    83.094697  83.154506  82.765560  83.277487
# Figueroa High School   76.403037  76.539974  76.884344  77.151369
# Ford High School       77.361345  77.672316  76.918058  76.179963
# Griffin High School    82.044010  84.229064  83.842105  83.356164
# Hernandez High School  77.438495  77.337408  77.136029  77.186567
# Holden High School     83.787402  83.429825  85.000000  82.855422
# Huang High School      77.027251  75.908735  76.446602  77.225641
# Johnson High School    77.187857  76.691117  77.491653  76.863248
# Pena High School       83.625455  83.372000  84.328125  84.121547
# Rodriguez High School  76.859966  76.612500  76.395626  77.690748
# Shelton High School    83.420755  82.917411  83.383495  83.778976
# Thomas High School           NaN  83.087886  83.498795  83.497041
# ...

# %%
# Combine each Series for average reading scores by school into single DataFrame.
reading_scores_by_grade_new = pd.DataFrame({
              "9th": ninth_grade_reading_scores_new,
              "10th": tenth_grade_reading_scores_new,
              "11th": eleventh_grade_reading_scores_new,
              "12th": twelfth_grade_reading_scores_new})

reading_scores_by_grade_new
# Out:
#                              9th       10th       11th       12th
# school_name
# Bailey High School     81.303155  80.907183  80.945643  80.912451
# Cabrera High School    83.676136  84.253219  83.788382  84.287958
# Figueroa High School   81.198598  81.408912  80.640339  81.384863
# Ford High School       80.632653  81.262712  80.403642  80.662338
# Griffin High School    83.369193  83.706897  84.288089  84.013699
# Hernandez High School  80.866860  80.660147  81.396140  80.857143
# Holden High School     83.677165  83.324561  83.815534  84.698795
# Huang High School      81.290284  81.512386  81.417476  80.305983
# Johnson High School    81.260714  80.773431  80.616027  81.227564
# Pena High School       83.807273  83.612000  84.335938  84.591160
# Rodriguez High School  80.993127  80.629808  80.864811  80.376426
# Shelton High School    84.122642  83.441964  84.373786  82.781671
# Thomas High School           NaN  84.254157  83.585542  83.831361
# ...

# %%
#Format each grade column.
math_scores_by_grade_new["9th"] = math_scores_by_grade_new["9th"].map("{:.1f}".format)

math_scores_by_grade_new["10th"] = math_scores_by_grade_new["10th"].map("{:.1f}".format)

math_scores_by_grade_new["11th"] = math_scores_by_grade_new["11th"].map("{:.1f}".format)

math_scores_by_grade_new["12th"] = math_scores_by_grade_new["12th"].map("{:.1f}".format)

# Make sure the columns are in the correct order.
math_scores_by_grade_new = math_scores_by_grade_new[
                 ["9th", "10th", "11th", "12th"]]

# Remove the index name.
math_scores_by_grade_new.index.name = None
# Display the DataFrame.
math_scores_by_grade_new.head()
# Out:
#                        9th  10th  11th  12th
# Bailey High School    77.1  77.0  77.5  76.5
# Cabrera High School   83.1  83.2  82.8  83.3
# Figueroa High School  76.4  76.5  76.9  77.2
# Ford High School      77.4  77.7  76.9  76.2
# Griffin High School   82.0  84.2  83.8  83.4

# %%
math_scores_by_grade_new
# Out:
#                         9th  10th  11th  12th
# Bailey High School     77.1  77.0  77.5  76.5
# Cabrera High School    83.1  83.2  82.8  83.3
# Figueroa High School   76.4  76.5  76.9  77.2
# Ford High School       77.4  77.7  76.9  76.2
# Griffin High School    82.0  84.2  83.8  83.4
# Hernandez High School  77.4  77.3  77.1  77.2
# Holden High School     83.8  83.4  85.0  82.9
# Huang High School      77.0  75.9  76.4  77.2
# Johnson High School    77.2  76.7  77.5  76.9
# Pena High School       83.6  83.4  84.3  84.1
# Rodriguez High School  76.9  76.6  76.4  77.7
# Shelton High School    83.4  82.9  83.4  83.8
# Thomas High School      nan  83.1  83.5  83.5
# Wilson High School     83.1  83.7  83.2  83.0
# Wright High School     83.3  84.0  83.8  83.6

# %%
# Format each grade column.
reading_scores_by_grade_new["9th"] = reading_scores_by_grade_new["9th"].map("{:.1f}".format)

reading_scores_by_grade_new["10th"] = reading_scores_by_grade_new["10th"].map("{:.1f}".format)

reading_scores_by_grade_new["11th"] = reading_scores_by_grade_new["11th"].map("{:.1f}".format)

reading_scores_by_grade_new["12th"] = reading_scores_by_grade_new["12th"].map("{:.1f}".format)

# Make sure the columns are in the correct order.
reading_scores_by_grade_new = reading_scores_by_grade_new[
                 ["9th", "10th", "11th", "12th"]]

# Remove the index name.
reading_scores_by_grade_new.index.name = None
# Display the DataFrame.
reading_scores_by_grade_new
# Out:
#                         9th  10th  11th  12th
# Bailey High School     81.3  80.9  80.9  80.9
# Cabrera High School    83.7  84.3  83.8  84.3
# Figueroa High School   81.2  81.4  80.6  81.4
# Ford High School       80.6  81.3  80.4  80.7
# Griffin High School    83.4  83.7  84.3  84.0
# Hernandez High School  80.9  80.7  81.4  80.9
# Holden High School     83.7  83.3  83.8  84.7
# Huang High School      81.3  81.5  81.4  80.3
# Johnson High School    81.3  80.8  80.6  81.2
# Pena High School       83.8  83.6  84.3  84.6
# Rodriguez High School  81.0  80.6  80.9  80.4
# Shelton High School    84.1  83.4  84.4  82.8
# Thomas High School      nan  84.3  83.6  83.8
# Wilson High School     83.9  84.0  83.8  84.3
# Wright High School     83.8  83.8  84.2  84.1

# %%
# Get the descriptive statistics for the per_school_capita.
per_school_capita_new.describe()
# Out:
# count     15.000000
# mean     620.066667
# std       28.544368
# min      578.000000
# 25%      591.500000
# 50%      628.000000
# 75%      641.500000
# max      655.000000
# dtype: float64

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins_new = [0, 585, 615, 645, 675]
pd.cut(per_school_capita_new, spending_bins_new)
# Out:
# Bailey High School       (615, 645]
# Cabrera High School        (0, 585]
# Figueroa High School     (615, 645]
# Ford High School         (615, 645]
# Griffin High School      (615, 645]
# Hernandez High School    (645, 675]
# Holden High School         (0, 585]
# Huang High School        (645, 675]
# Johnson High School      (645, 675]
# Pena High School         (585, 615]
# Rodriguez High School    (615, 645]
# Shelton High School      (585, 615]
# Thomas High School       (615, 645]
# Wilson High School         (0, 585]
# Wright High School         (0, 585]
# dtype: category
# Categories (4, interval[int64]): [(0, 585] < (585, 615] < (615, 645] < (645, 675]]

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins_new = [585, 615, 645, 675]
pd.cut(per_school_capita_new, spending_bins_new)
# Out:
# Bailey High School       (615.0, 645.0]
# Cabrera High School                 NaN
# Figueroa High School     (615.0, 645.0]
# Ford High School         (615.0, 645.0]
# Griffin High School      (615.0, 645.0]
# Hernandez High School    (645.0, 675.0]
# Holden High School                  NaN
# Huang High School        (645.0, 675.0]
# Johnson High School      (645.0, 675.0]
# Pena High School         (585.0, 615.0]
# Rodriguez High School    (615.0, 645.0]
# Shelton High School      (585.0, 615.0]
# Thomas High School       (615.0, 645.0]
# Wilson High School                  NaN
# Wright High School                  NaN
# dtype: category
# Categories (3, interval[int64]): [(585, 615] < (615, 645] < (645, 675]]

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins_new = [0, 585, 615, 645, 675]
per_school_capita_new.groupby(pd.cut(per_school_capita_new, spending_bins_new)).count()
# Out:
# (0, 585]      4
# (585, 615]    2
# (615, 645]    6
# (645, 675]    3
# dtype: int64

# %%
# Cut the per_school_capita into the spending ranges.
spending_bins_new = [0, 585, 630, 645, 675]
per_school_capita_new.groupby(pd.cut(per_school_capita_new, spending_bins_new)).count()
# Out:
# (0, 585]      4
# (585, 630]    4
# (630, 645]    4
# (645, 675]    3
# dtype: int64

# %%
# Establish the spending bins and group names.
spending_bins_new = [0, 585, 630, 645, 675]
group_names_new = ["<$584", "$585-629", "$630-644", "$645-675"]

# %%
# Categorize spending based on the bins.
per_school_summary_new_df["Spending Ranges (Per Student)"] = pd.cut(per_school_capita_new, spending_bins_new, labels=group_names_new)

per_school_summary_new_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
# Calculate averages for the desired columns.
spending_math_scores_new = per_school_summary_new_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Math Score"]

spending_reading_scores_new = per_school_summary_new_df.groupby(["Spending Ranges (Per Student)"]).mean()["Average Reading Score"]

spending_passing_math_new = per_school_summary_new_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Math"]

spending_passing_reading_new = per_school_summary_new_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Passing Reading"]

overall_passing_spending_new = per_school_summary_new_df.groupby(["Spending Ranges (Per Student)"]).mean()["% Overall Passing"]

# %%
# Assemble into DataFrame. 
spending_summary_new_df = pd.DataFrame({
          "Average Math Score" : spending_math_scores_new,
          "Average Reading Score": spending_reading_scores_new,
          "% Passing Math": spending_passing_math_new,
          "% Passing Reading": spending_passing_reading_new,
          "% Overall Passing": overall_passing_spending_new})

spending_summary_new_df
# Out:
#                                Average Math Score  Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                   83.455399              83.933814
# $585-629                                81.899826              83.155286
# $630-644                                78.502002              81.636261
# $645-675                                76.997210              81.027843
#
#                                % Passing Math  % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                               93.460096          96.610877
# $585-629                            87.133538          92.718205
# $630-644                            66.893995          77.480478
# $645-675                            66.164813          81.133951
#
#                                % Overall Passing
# Spending Ranges (Per Student)
# <$584                                  90.369459
# $585-629                               81.418596
# ...

# %%
# Formatting
spending_summary_new_df["Average Math Score"] = spending_summary_new_df["Average Math Score"].map("{:.1f}".format)

spending_summary_new_df["Average Reading Score"] = spending_summary_new_df["Average Reading Score"].map("{:.1f}".format)

spending_summary_new_df["% Passing Math"] = spending_summary_new_df["% Passing Math"].map("{:.0f}".format)

spending_summary_new_df["% Passing Reading"] = spending_summary_new_df["% Passing Reading"].map("{:.0f}".format)

spending_summary_new_df["% Overall Passing"] = spending_summary_new_df["% Overall Passing"].map("{:.0f}".format)

spending_summary_new_df
# Out:
#                               Average Math Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$584                                       83.5                  83.9
# $585-629                                    81.9                  83.2
# $630-644                                    78.5                  81.6
# $645-675                                    77.0                  81.0
#
#                               % Passing Math % Passing Reading  \
# Spending Ranges (Per Student)
# <$584                                     93                97
# $585-629                                  87                93
# $630-644                                  67                77
# $645-675                                  66                81
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$584                                        90
# $585-629                                     81
# $630-644                                     56
# ...

# %%
# Establish the bins.
size_bins_new = [0, 1000, 2000, 5000]
group_names_new = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# %%
# Categorize spending based on the bins.
per_school_summary_new_df["School Size"] = pd.cut(per_school_summary_new_df["Total Students"], size_bins_new, labels=group_names_new)

per_school_summary_new_df
# Out:
#                       School Type  Total Students Total School Budget  \
# Bailey High School       District            4976       $3,124,928.00
# Cabrera High School       Charter            1858       $1,081,356.00
# Figueroa High School     District            2949       $1,884,411.00
# Ford High School         District            2739       $1,763,916.00
# Griffin High School       Charter            1468         $917,500.00
# Hernandez High School    District            4635       $3,022,020.00
# Holden High School        Charter             427         $248,087.00
# Huang High School        District            2917       $1,910,635.00
# Johnson High School      District            4761       $3,094,650.00
# Pena High School          Charter             962         $585,858.00
# Rodriguez High School    District            3999       $2,547,363.00
# Shelton High School       Charter            1761       $1,056,600.00
# ...

# %%
# Calculate averages for the desired columns.
size_math_scores_new = per_school_summary_new_df.groupby(["School Size"]).mean()["Average Math Score"]

size_reading_scores_new = per_school_summary_new_df.groupby(["School Size"]).mean()["Average Reading Score"]

size_passing_math_new = per_school_summary_new_df.groupby(["School Size"]).mean()["% Passing Math"]

size_passing_reading_new = per_school_summary_new_df.groupby(["School Size"]).mean()["% Passing Reading"]

size_overall_passing_new = per_school_summary_new_df.groupby(["School Size"]).mean()["% Overall Passing"]

# %%
# Assemble into DataFrame.
size_summary_new_df = pd.DataFrame({
          "Average Math Score" : size_math_scores_new,
          "Average Reading Score": size_reading_scores_new,
          "% Passing Math": size_passing_math_new,
          "% Passing Reading": size_passing_reading_new,
          "% Overall Passing": size_overall_passing_new})

size_summary_new_df
# Out:
#                     Average Math Score  Average Reading Score  % Passing Math  \
# School Size
# Small (<1000)                83.821598              83.929843       93.550225
# Medium (1000-2000)           83.361201              83.873869       88.327523
# Large (2000-5000)            77.746417              81.344493       69.963361
#
#                     % Passing Reading  % Overall Passing
# School Size
# Small (<1000)               96.099437          89.883853
# Medium (1000-2000)          91.261628          85.447223
# Large (2000-5000)           82.766634          58.286003

# %%
# Formatting.
size_summary_new_df["Average Math Score"] = size_summary_new_df["Average Math Score"].map("{:.1f}".format)

size_summary_new_df["Average Reading Score"] = size_summary_new_df["Average Reading Score"].map("{:.1f}".format)

size_summary_new_df["% Passing Math"] = size_summary_new_df["% Passing Math"].map("{:.0f}".format)

size_summary_new_df["% Passing Reading"] = size_summary_new_df["% Passing Reading"].map("{:.0f}".format)

size_summary_new_df["% Overall Passing"] = size_summary_new_df["% Overall Passing"].map("{:.0f}".format)

size_summary_new_df
# Out:
#                    Average Math Score Average Reading Score % Passing Math  \
# School Size
# Small (<1000)                    83.8                  83.9             94
# Medium (1000-2000)               83.4                  83.9             88
# Large (2000-5000)                77.7                  81.3             70
#
#                    % Passing Reading % Overall Passing
# School Size
# Small (<1000)                     96                90
# Medium (1000-2000)                91                85
# Large (2000-5000)                 83                58

# %%
# Calculate averages for the desired columns. 
type_math_scores_new = per_school_summary_new_df.groupby(["School Type"]).mean()["Average Math Score"]

type_reading_scores_new = per_school_summary_new_df.groupby(["School Type"]).mean()["Average Reading Score"]

type_passing_math_new = per_school_summary_new_df.groupby(["School Type"]).mean()["% Passing Math"]

type_passing_reading_new = per_school_summary_new_df.groupby(["School Type"]).mean()["% Passing Reading"]

type_overall_passing_new = per_school_summary_new_df.groupby(["School Type"]).mean()["% Overall Passing"]

# %%
# Assemble into DataFrame.
type_summary_new_df = pd.DataFrame({
          "Average Math Score" : type_math_scores_new,
          "Average Reading Score": type_reading_scores_new,
          "% Passing Math": type_passing_math_new,
          "% Passing Reading": type_passing_reading_new,
          "% Overall Passing": type_overall_passing_new})

type_summary_new_df
# Out:
#              Average Math Score  Average Reading Score  % Passing Math  \
# School Type
# Charter               83.465425              83.902315       90.325723
# District              76.956733              80.966636       66.548453
#
#              % Passing Reading  % Overall Passing
# School Type
# Charter              93.130832          87.198299
# District             80.799062          53.672208

# %%
# Formatting
type_summary_new_df["Average Math Score"] = type_summary_new_df["Average Math Score"].map("{:.1f}".format)

type_summary_new_df["Average Reading Score"] = type_summary_new_df["Average Reading Score"].map("{:.1f}".format)

type_summary_new_df["% Passing Math"] = type_summary_new_df["% Passing Math"].map("{:.0f}".format)

type_summary_new_df["% Passing Reading"] = type_summary_new_df["% Passing Reading"].map("{:.0f}".format)

type_summary_new_df["% Overall Passing"] = type_summary_new_df["% Overall Passing"].map("{:.0f}".format)

type_summary_new_df
# Out:
#             Average Math Score Average Reading Score % Passing Math  \
# School Type
# Charter                   83.5                  83.9             90
# District                  77.0                  81.0             67
#
#             % Passing Reading % Overall Passing
# School Type
# Charter                    93                87
# District                   81                54
